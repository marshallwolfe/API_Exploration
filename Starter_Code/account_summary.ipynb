# %% [markdown]
# # Budget Analysis
#
# ---
#
# ## Environment Setup

# %%
# Initial Imports
import os
import plaid
import requests
import datetime
import json
import pandas as pd
import hvplot.pandas
from dotenv import load_dotenv
from pathlib import Path
env_path = Path('/Users/marshallwolfe/Desktop') / '.env'
load_dotenv(env_path)
# %matplotlib inline

# %%
# Helper functions

def pretty_print_response(response):
    """
    This function formats a JSON file to pretty printing it in the screen.
    """
    print(json.dumps(response, indent=4, sort_keys=True))

# %%
# Set environment variables from the .env file
load_dotenv()
# Out:
# True

# %%
# Extract API keys from environment variables
PLAID_CLIENT_ID = os.getenv("PLAID_CLIENT_ID")
PLAID_SBX_SECRET_KEY = os.getenv("PLAID_SBX_SECRET_KEY")
PLAID_PUBLIC_KEY = os.getenv("PLAID_PUBLIC_KEY")

# %% [markdown]
# ---
#
# ## Plaid Access Token
#
# In this section, you will use the `plaid-python` API to generate the correct authentication tokens to access data in the free developer Sandbox. This mimics how you might connect to your own account or a customer account, but due to privacy issues, this homework will only require connecting to and analyzing the fake data from the developer sandbox that Plaid provides.
#
# Complete the following steps to generate an access token:
#
# 1. Create a client to connect to plaid
#
# 2. Use the client to generate a public token and request the following items: ['transactions', 'income', 'assets']
#
# 3. Exchange the public token for an access token
#
# 4. Test the access token by requesting and printing the available test accounts

# %% [markdown]
# ### 1. Create a client to connect to plaid

# %%
# Create the client object
client = plaid.Client(client_id=PLAID_CLIENT_ID, secret=PLAID_SBX_SECRET_KEY, public_key=PLAID_PUBLIC_KEY, environment='sandbox')

# %%
# Set the institution id
INSTITUTION_ID = "ins_109508"

# %% [markdown]
# ### 2. Generate a public token

# %%
# Create the public token}
create_tkn_response = client.Sandbox.public_token.create(INSTITUTION_ID, ['transactions','income','assets'])

# Print the public token
print(create_tkn_response)
# Out:
# {'public_token': 'public-sandbox-e5354964-82a1-486d-bab8-adbc341069d5', 'request_id': 'uSgfLWJ32zkn9Kd'}

# %% [markdown]
# ### 3. Exchange the public token for an access token

# %%
# Retrieve the access token
exchange_response = client.Item.public_token.exchange(create_tkn_response['public_token'])

# Print the access toke
print(exchange_response)
# Out:
# {'access_token': 'access-sandbox-f38b3738-a347-4f96-be78-109be0f32a21', 'item_id': 'p8dMVqNRg6FdxMP1wgZjFW1nxjxb56TLxxPLe', 'request_id': 'pLPieVYtpD3Rv80'}

# %%
# Store the access token in a Python variable
access_token = exchange_response['access_token']

# %% [markdown]
# ### 4. Fetch Accounts

# %%
# Retrieve accounts
client.Accounts.get(access_token)

# Print accounts
# Out:
# {'accounts': [{'account_id': 'NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e',
#    'balances': {'available': 100,
#     'current': 110,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '0000',
#    'name': 'Plaid Checking',
#    'official_name': 'Plaid Gold Standard 0% Interest Checking',
#    'subtype': 'checking',
#    'type': 'depository'},
#   {'account_id': 'PMdkpKvZrLTwgdP1qpxGhgMXyyyWRpS79Bn5z',
#    'balances': {'available': 200,
#     'current': 210,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '1111',
#    'name': 'Plaid Saving',
#    'official_name': 'Plaid Silver Standard 0.1% Interest Saving',
#    'subtype': 'savings',
#    'type': 'depository'},
#   {'account_id': 'ZKGEVPXybksNbaorjpReIJQ9oooWrzfgNAvmV',
#    'balances': {'available': None,
#     'current': 1000,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '2222',
#    'name': 'Plaid CD',
#    'official_name': 'Plaid Bronze Standard 0.2% Interest CD',
#    'subtype': 'cd',
#    'type': 'depository'},
#   {'account_id': 'MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP',
#    'balances': {'available': None,
#     'current': 410,
#     'iso_currency_code': 'USD',
#     'limit': 2000,
#     'unofficial_currency_code': None},
#    'mask': '3333',
#    'name': 'Plaid Credit Card',
#    'official_name': 'Plaid Diamond 12.5% APR Interest Credit Card',
#    'subtype': 'credit card',
#    'type': 'credit'},
#   {'account_id': '1jD6pzdMJAu8DMa3b649HLq6MMMadWc5xLaXo',
#    'balances': {'available': 43200,
#     'current': 43200,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '4444',
#    'name': 'Plaid Money Market',
#    'official_name': 'Plaid Platinum Standard 1.85% Interest Money Market',
#    'subtype': 'money market',
#    'type': 'depository'},
#   {'account_id': 'L7zpZmvNMAiq1NdarX8eH5Ve444EyKFPRvmKE',
#    'balances': {'available': None,
#     'current': 320.76,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '5555',
#    'name': 'Plaid IRA',
#    'official_name': None,
#    'subtype': 'ira',
#    'type': 'investment'},
#   {'account_id': 'p8dMVqNRg6FdxMP1wgZjFW1qAAAXEVSLWyqjQ',
#    'balances': {'available': None,
#     'current': 23631.9805,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '6666',
#    'name': 'Plaid 401k',
#    'official_name': None,
#    'subtype': '401k',
#    'type': 'investment'},
#   {'account_id': 'ogk1Vl4mb6iw3PRyQ9nehEaPooo9k6URzxP5Q',
#    'balances': {'available': None,
#     'current': 65262,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '7777',
#    'name': 'Plaid Student Loan',
#    'official_name': None,
#    'subtype': 'student',
#    'type': 'loan'},
#   {'account_id': 'geLMVEKapDsk9MRzXyQZTpD3qqqe4nCgwaGRR',
#    'balances': {'available': None,
#     'current': 56302.06,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '8888',
#    'name': 'Plaid Mortgage',
#    'official_name': None,
#    'subtype': 'mortgage',
#    'type': 'loan'}],
#  'item': {'available_products': ['auth',
#    'balance',
#    'credit_details',
#    'identity',
#    'investments',
#    'liabilities'],
#   'billed_products': ['assets', 'income', 'transactions'],
#   'consent_expiration_time': None,
#   'error': None,
#   'institution_id': 'ins_109508',
#   'item_id': 'p8dMVqNRg6FdxMP1wgZjFW1nxjxb56TLxxPLe',
#   'webhook': ''},
#  'request_id': 'CCCukbFtFO1M1LT'}

# %% [markdown]
# ---
#
# # Account Transactions with Plaid
#
# In this section, you will use the Plaid Python SDK to connect to the Developer Sandbox account and grab a list of transactions. You will need to complete the following steps:
#
#
# 1. Use the access token to fetch the transactions for the last 90 days
#
# 2. Print the categories for each transaction type
#
# 3. Create a new DataFrame using the following fields from the JSON transaction data: `date, name, amount, category`. (For categories with more than one label, just use the first category label in the list)
#
# 4. Convert the data types to the appropriate types (i.e. datetimeindex for the date and float for the amount)

# %% [markdown]
# ### 1. Fetch the Transactions for the last 90 days

# %%
# Set the start and end date 90 days from today
start_date = '{:%Y-%m-%d}'.format(datetime.datetime.now() + datetime.timedelta(-90))
end_date = '{:%Y-%m-%d}'.format(datetime.datetime.now())

# Retrieve the transactions for the last 90 days
transaction_response = client.Transactions.get(access_token,start_date,end_date)
transactions = transaction_response['transactions']

# Print the transactions
pretty_print_response(transactions)
# Out:
# [
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2020-05-25",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Tectra Inc",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "dPAMVov3gRCwr5yN3KgJh17BywxjMLfZQMRvm",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 2078.5,
#         "authorized_date": null,
#         "category": [
#             "Payment"
#         ],
#         "category_id": "16000000",
#         "date": "2020-05-24",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "AUTOMATIC PAYMENT - THANK",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "wBeRVdMX36fg7MldNZjKIzLa139Zb4CroNmko",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Fast Food"
#         ],
#         "category_id": "13005032",
#         "date": "2020-05-24",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "KFC",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "4Qgn8xNk6AfQP6LewdbaTGoX7WagReCdArLX7",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Shops",
#             "Sporting Goods"
#         ],
#         "category_id": "19046000",
#         "date": "2020-05-24",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Madison Bicycle Shop",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "aaL6V1vrkRuJLEnP9pw8hmgk8JyB5zt7QaD8x",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "PMdkpKvZrLTwgdP1qpxGhgMXyyyWRpS79Bn5z",
#         "account_owner": null,
#         "amount": 25,
#         "authorized_date": null,
#         "category": [
#             "Payment",
#             "Credit Card"
#         ],
#         "category_id": "16001000",
#         "date": "2020-05-15",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CREDIT CARD 3333 PAYMENT *//",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "BzgLxpEKwocqa6Gv3dVNHlQgGLxNJPCw8Wgd3",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": 5.4,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Taxi"
#         ],
#         "category_id": "22016000",
#         "date": "2020-05-15",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "k1rM5n3QwRTAKkXDzd38UNM3JA1lGeCWdQoZR",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "1jD6pzdMJAu8DMa3b649HLq6MMMadWc5xLaXo",
#         "account_owner": null,
#         "amount": 5850,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Debit"
#         ],
#         "category_id": "21006000",
#         "date": "2020-05-14",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "ACH Electronic CreditGUSTO PAY 123456",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": "ACH",
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "k1rM5n3QwRTAKkXDzd38UNM3JA1lGeCWdQoN1",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "ZKGEVPXybksNbaorjpReIJQ9oooWrzfgNAvmV",
#         "account_owner": null,
#         "amount": 1000,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Deposit"
#         ],
#         "category_id": "21007000",
#         "date": "2020-05-14",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CD DEPOSIT .INITIAL.",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "x3ZDVa1Wx6HveM6n1GdRFqvZmWxe3wInV7ex8",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 78.5,
#         "authorized_date": null,
#         "category": [
#             "Recreation",
#             "Gyms and Fitness Centers"
#         ],
#         "category_id": "17018000",
#         "date": "2020-05-13",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Touchstone Climbing",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "5Z1nEdPM7XclLM86xmN3t1gjaQMVdofZ7w8Rd",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": -500,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2020-05-13",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "lLzmVbxQ7RumvbWwog3eH87NxmDV5vuZdwRbG",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": 12,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Fast Food"
#         ],
#         "category_id": "13005032",
#         "date": "2020-05-12",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": "3322"
#         },
#         "name": "McDonald's",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "qEaJVKP1l6s4dP9DkAMVunL5JpG1zmud7mRwe",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": 4.33,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Coffee Shop"
#         ],
#         "category_id": "13005043",
#         "date": "2020-05-12",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Starbucks",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "KjrAQbvNRLuLMNxbJ6RlTQXEP5eD81iVAZ1z4",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": 89.4,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2020-05-11",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "SparkFun",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "rl47VrkWq6FoaPKbvDBnTZBX7J9Eejcl6P1Z8",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "PMdkpKvZrLTwgdP1qpxGhgMXyyyWRpS79Bn5z",
#         "account_owner": null,
#         "amount": -4.22,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Credit"
#         ],
#         "category_id": "21005000",
#         "date": "2020-05-10",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "INTRST PYMNT",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "3eDng34XPZsrxaozvD7eTgRkPQBw45uqnrEkk",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2020-04-30",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "JPKwenvNkyCxZN3jXmkzSPaQVL69jDFdg4kak",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": 6.33,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Taxi"
#         ],
#         "category_id": "22016000",
#         "date": "2020-04-28",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "zdElqNpwJ6idZJEj379wF7DKgldA5JhoL7QxP",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2020-04-25",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Tectra Inc",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "V87ZAdvypzFjXpM4EgQbHeRkw1NEJzfWwL5zW",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 2078.5,
#         "authorized_date": null,
#         "category": [
#             "Payment"
#         ],
#         "category_id": "16000000",
#         "date": "2020-04-24",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "AUTOMATIC PAYMENT - THANK",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "D39nagAzoEHxNvlpyVqjSM8eaJdbj1Hvk9lbz",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Fast Food"
#         ],
#         "category_id": "13005032",
#         "date": "2020-04-24",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "KFC",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "XlDbn4vVo3FdBJL6y89rFz5gVyKeqAud3zMGp",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Shops",
#             "Sporting Goods"
#         ],
#         "category_id": "19046000",
#         "date": "2020-04-24",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Madison Bicycle Shop",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "6M1nWajbXkTP59pwNlWxcP37o6QLyzCgyMa4a",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "PMdkpKvZrLTwgdP1qpxGhgMXyyyWRpS79Bn5z",
#         "account_owner": null,
#         "amount": 25,
#         "authorized_date": null,
#         "category": [
#             "Payment",
#             "Credit Card"
#         ],
#         "category_id": "16001000",
#         "date": "2020-04-15",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CREDIT CARD 3333 PAYMENT *//",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "jMKLVGBmpRTmqxgrK1z8HD1VD1Vxo3i1Bzjnz",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": 5.4,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Taxi"
#         ],
#         "category_id": "22016000",
#         "date": "2020-04-15",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "WEeXGavyJBsELD1nj8yNTZ67Z67rzDtlDA5Jq",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "1jD6pzdMJAu8DMa3b649HLq6MMMadWc5xLaXo",
#         "account_owner": null,
#         "amount": 5850,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Debit"
#         ],
#         "category_id": "21006000",
#         "date": "2020-04-14",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "ACH Electronic CreditGUSTO PAY 123456",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": "ACH",
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "rl47VrkWq6FoaPKbvDBnTZBew5D9xWflnqWnM",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "ZKGEVPXybksNbaorjpReIJQ9oooWrzfgNAvmV",
#         "account_owner": null,
#         "amount": 1000,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Deposit"
#         ],
#         "category_id": "21007000",
#         "date": "2020-04-14",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CD DEPOSIT .INITIAL.",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "lLzmVbxQ7RumvbWwog3eH875kZJDqzuZkG594",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 78.5,
#         "authorized_date": null,
#         "category": [
#             "Recreation",
#             "Gyms and Fitness Centers"
#         ],
#         "category_id": "17018000",
#         "date": "2020-04-13",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Touchstone Climbing",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "RL4wgzvyBlu6J47mgp9xuDMj8vGpwkCRBrx8L",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": -500,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2020-04-13",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "ExgV48GB7LunPoqEW739hN61N61pvVCX1vMpz",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": 12,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Fast Food"
#         ],
#         "category_id": "13005032",
#         "date": "2020-04-12",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": "3322"
#         },
#         "name": "McDonald's",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "geLMVEKapDsk9MRzXyQZTpDvpDvJ8EfgwaGvP",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": 4.33,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Coffee Shop"
#         ],
#         "category_id": "13005043",
#         "date": "2020-04-12",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Starbucks",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "8L8JGNej6oueXkWBxLbqhBQ9BQ9m5lcwG4RkN",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": 89.4,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2020-04-11",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "SparkFun",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "ogk1Vl4mb6iw3PRyQ9nehEa8Ea8AGJhRzxPWr",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "PMdkpKvZrLTwgdP1qpxGhgMXyyyWRpS79Bn5z",
#         "account_owner": null,
#         "amount": -4.22,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Credit"
#         ],
#         "category_id": "21005000",
#         "date": "2020-04-10",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "INTRST PYMNT",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "PMdkpKvZrLTwgdP1qpxGhgM9gM9oEVU79Bnqm",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2020-03-31",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "vz7gVxZWB6cXjJgoLyx9tmJMyq8Go4TWE4Grd",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": 6.33,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Taxi"
#         ],
#         "category_id": "22016000",
#         "date": "2020-03-29",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "p8dMVqNRg6FdxMP1wgZjFW1lW1lko9TLWyqAK",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2020-03-26",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Tectra Inc",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "9pgRnPQMkoFnl5z3de4Lh6QyB7XjZPCR5bej1",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 2078.5,
#         "authorized_date": null,
#         "category": [
#             "Payment"
#         ],
#         "category_id": "16000000",
#         "date": "2020-03-25",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "AUTOMATIC PAYMENT - THANK",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "yxZkl4LWd6uXvR8Ll74dt18zB5jZMpTylL1xd",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Fast Food"
#         ],
#         "category_id": "13005032",
#         "date": "2020-03-25",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "KFC",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "mpBMVmdXJ6FDzxrnPZp8fe4DwBJELKfLWwK6m",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Shops",
#             "Sporting Goods"
#         ],
#         "category_id": "19046000",
#         "date": "2020-03-25",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Madison Bicycle Shop",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "b49DVLvzpRF3Pk59wZXpIpyZmgM7R9CVdy98k",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "PMdkpKvZrLTwgdP1qpxGhgMXyyyWRpS79Bn5z",
#         "account_owner": null,
#         "amount": 25,
#         "authorized_date": null,
#         "category": [
#             "Payment",
#             "Credit Card"
#         ],
#         "category_id": "16001000",
#         "date": "2020-03-16",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CREDIT CARD 3333 PAYMENT *//",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "NQ381lvjqLfapL4GAEkrTwWqwWqAQ6FWgBzRk",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": 5.4,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Taxi"
#         ],
#         "category_id": "22016000",
#         "date": "2020-03-16",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "L7zpZmvNMAiq1NdarX8eH5VG5VGJW9uPRvmVl",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "1jD6pzdMJAu8DMa3b649HLq6MMMadWc5xLaXo",
#         "account_owner": null,
#         "amount": 5850,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Debit"
#         ],
#         "category_id": "21006000",
#         "date": "2020-03-15",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "ACH Electronic CreditGUSTO PAY 123456",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": "ACH",
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "KjrAQbvNRLuLMNxbJ6RlTQX8rAneolsVLW7LA",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "ZKGEVPXybksNbaorjpReIJQ9oooWrzfgNAvmV",
#         "account_owner": null,
#         "amount": 1000,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Deposit"
#         ],
#         "category_id": "21007000",
#         "date": "2020-03-15",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CD DEPOSIT .INITIAL.",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "k1rM5n3QwRTAKkXDzd38UNMGrjk1mLFWXg3PB",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 78.5,
#         "authorized_date": null,
#         "category": [
#             "Recreation",
#             "Gyms and Fitness Centers"
#         ],
#         "category_id": "17018000",
#         "date": "2020-03-14",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Touchstone Climbing",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "no3RVyaQ46t6k95jnXeZuw4jzMQb17i6np7vo",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": -500,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2020-03-14",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "1jD6pzdMJAu8DMa3b649HLqQLqQy91i5xLaAq",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": 12,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Fast Food"
#         ],
#         "category_id": "13005032",
#         "date": "2020-03-13",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": "3322"
#         },
#         "name": "McDonald's",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "ZKGEVPXybksNbaorjpReIJQBJQBDyXfgNAvdg",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": 4.33,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Coffee Shop"
#         ],
#         "category_id": "13005043",
#         "date": "2020-03-13",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Starbucks",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "MeBgMyvNlnsBL4adezbmurB1rB1veDu9Ew5dL",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": 89.4,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2020-03-12",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "SparkFun",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "Q1aporwGzRTDWEjbwra3f7L57L5kQbUpJ4nqk",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "PMdkpKvZrLTwgdP1qpxGhgMXyyyWRpS79Bn5z",
#         "account_owner": null,
#         "amount": -4.22,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Credit"
#         ],
#         "category_id": "21005000",
#         "date": "2020-03-11",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "INTRST PYMNT",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "4Qgn8xNk6AfQP6LewdbaTGogGogNDnUdZNKGW",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "MeBgMyvNlnsBL4adezbmurB4kkkmKpi9Ew5pP",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2020-03-01",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "GaEnPWvxwVux71rGDzvqSdxanZk74yf1QrNkl",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "NQ381lvjqLfapL4GAEkrTwWX111LEpFWgBz8e",
#         "account_owner": null,
#         "amount": 6.33,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Taxi"
#         ],
#         "category_id": "22016000",
#         "date": "2020-02-28",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "ej8MVglx6RuqWM96wl84HZe4Ze419jtLzRXoy",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     }
# ]

# %% [markdown]
# ### 2. Print the categories for each transaction

# %%
# Create a for-loop to print the categories for each transaction
for transaction in transactions:
    print(transaction['category'])
# Out:
# ['Food and Drink', 'Restaurants']
# ['Payment']
# ['Food and Drink', 'Restaurants', 'Fast Food']
# ['Shops', 'Sporting Goods']
# ['Payment', 'Credit Card']
# ['Travel', 'Taxi']
# ['Transfer', 'Debit']
# ['Transfer', 'Deposit']
# ['Recreation', 'Gyms and Fitness Centers']
# ['Travel', 'Airlines and Aviation Services']
# ['Food and Drink', 'Restaurants', 'Fast Food']
# ['Food and Drink', 'Restaurants', 'Coffee Shop']
# ['Food and Drink', 'Restaurants']
# ['Transfer', 'Credit']
# ['Travel', 'Airlines and Aviation Services']
# ['Travel', 'Taxi']
# ['Food and Drink', 'Restaurants']
# ['Payment']
# ['Food and Drink', 'Restaurants', 'Fast Food']
# ['Shops', 'Sporting Goods']
# ['Payment', 'Credit Card']
# ['Travel', 'Taxi']
# ['Transfer', 'Debit']
# ['Transfer', 'Deposit']
# ['Recreation', 'Gyms and Fitness Centers']
# ['Travel', 'Airlines and Aviation Services']
# ['Food and Drink', 'Restaurants', 'Fast Food']
# ['Food and Drink', 'Restaurants', 'Coffee Shop']
# ['Food and Drink', 'Restaurants']
# ['Transfer', 'Credit']
# ['Travel', 'Airlines and Aviation Services']
# ['Travel', 'Taxi']
# ['Food and Drink', 'Restaurants']
# ['Payment']
# ['Food and Drink', 'Restaurants', 'Fast Food']
# ['Shops', 'Sporting Goods']
# ['Payment', 'Credit Card']
# ['Travel', 'Taxi']
# ['Transfer', 'Debit']
# ['Transfer', 'Deposit']
# ['Recreation', 'Gyms and Fitness Centers']
# ['Travel', 'Airlines and Aviation Services']
# ['Food and Drink', 'Restaurants', 'Fast Food']
# ['Food and Drink', 'Restaurants', 'Coffee Shop']
# ['Food and Drink', 'Restaurants']
# ['Transfer', 'Credit']
# ['Travel', 'Airlines and Aviation Services']
# ['Travel', 'Taxi']

# %% [markdown]
# ### 3. Create a new DataFrame using the following fields from the JSON transaction data: `date`, `name`, `amount`, `category`.
#
# (For categories with more than one label, just use the first category label in the list)

# %%
# Define an empty DataFrame and set the columns as date, name, amount, and category

transaction_df = pd.DataFrame(columns=['date', 'name', 'amount', 'category'])

dates = []
names = []
amounts = []
categories = []

for transaction in transactions:
    dates.append(transaction['date'])
    names.append(transaction['name'])
    amounts.append(transaction['amount'])
    categories.append(transaction['category'][0])
    
transaction_df['date'] = dates
transaction_df['name'] = names
transaction_df['amount'] = amounts
transaction_df['category'] = categories

transaction_df
# Out:
#           date                                   name   amount        category
# 0   2020-05-25                             Tectra Inc   500.00  Food and Drink
# 1   2020-05-24              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 2   2020-05-24                                    KFC   500.00  Food and Drink
# 3   2020-05-24                   Madison Bicycle Shop   500.00           Shops
# 4   2020-05-15           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 5   2020-05-15                                   Uber     5.40          Travel
# 6   2020-05-14  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 7   2020-05-14                   CD DEPOSIT .INITIAL.  1000.00        Transfer
# 8   2020-05-13                    Touchstone Climbing    78.50      Recreation
# 9   2020-05-13                        United Airlines  -500.00          Travel
# 10  2020-05-12                             McDonald's    12.00  Food and Drink
# 11  2020-05-12                              Starbucks     4.33  Food and Drink
# 12  2020-05-11                               SparkFun    89.40  Food and Drink
# 13  2020-05-10                           INTRST PYMNT    -4.22        Transfer
# 14  2020-04-30                        United Airlines   500.00          Travel
# 15  2020-04-28                                   Uber     6.33          Travel
# 16  2020-04-25                             Tectra Inc   500.00  Food and Drink
# 17  2020-04-24              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 18  2020-04-24                                    KFC   500.00  Food and Drink
# 19  2020-04-24                   Madison Bicycle Shop   500.00           Shops
# 20  2020-04-15           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 21  2020-04-15                                   Uber     5.40          Travel
# 22  2020-04-14  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 23  2020-04-14                   CD DEPOSIT .INITIAL.  1000.00        Transfer
# 24  2020-04-13                    Touchstone Climbing    78.50      Recreation
# 25  2020-04-13                        United Airlines  -500.00          Travel
# 26  2020-04-12                             McDonald's    12.00  Food and Drink
# 27  2020-04-12                              Starbucks     4.33  Food and Drink
# 28  2020-04-11                               SparkFun    89.40  Food and Drink
# 29  2020-04-10                           INTRST PYMNT    -4.22        Transfer
# 30  2020-03-31                        United Airlines   500.00          Travel
# 31  2020-03-29                                   Uber     6.33          Travel
# 32  2020-03-26                             Tectra Inc   500.00  Food and Drink
# 33  2020-03-25              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 34  2020-03-25                                    KFC   500.00  Food and Drink
# 35  2020-03-25                   Madison Bicycle Shop   500.00           Shops
# 36  2020-03-16           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 37  2020-03-16                                   Uber     5.40          Travel
# 38  2020-03-15  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 39  2020-03-15                   CD DEPOSIT .INITIAL.  1000.00        Transfer
# 40  2020-03-14                    Touchstone Climbing    78.50      Recreation
# 41  2020-03-14                        United Airlines  -500.00          Travel
# 42  2020-03-13                             McDonald's    12.00  Food and Drink
# 43  2020-03-13                              Starbucks     4.33  Food and Drink
# 44  2020-03-12                               SparkFun    89.40  Food and Drink
# 45  2020-03-11                           INTRST PYMNT    -4.22        Transfer
# 46  2020-03-01                        United Airlines   500.00          Travel
# 47  2020-02-28                                   Uber     6.33          Travel

# %% [markdown]
# ### 4. Convert the data types to the appropriate types
#
# (i.e. datetimeindex for the date and float for the amount)

# %%
# Display data types
transaction_df.dtypes
# Out:
# date         object
# name         object
# amount      float64
# category     object
# dtype: object

# %%
# Make any required data type transformation
transaction_df['date'] = pd.DatetimeIndex(transaction_df['date'])

# %%
transaction_df.dtypes
# Out:
# date        datetime64[ns]
# name                object
# amount             float64
# category            object
# dtype: object

# %%
# Set the date column as index
transaction_df.set_index(transaction_df['date'], inplace=True)

# Display sample data
transaction_df.tail()
# Out:
#                  date             name  amount        category
# date
# 2020-03-13 2020-03-13        Starbucks    4.33  Food and Drink
# 2020-03-12 2020-03-12         SparkFun   89.40  Food and Drink
# 2020-03-11 2020-03-11     INTRST PYMNT   -4.22        Transfer
# 2020-03-01 2020-03-01  United Airlines  500.00          Travel
# 2020-02-28 2020-02-28             Uber    6.33          Travel

# %%
# Drop date column
transaction_df.drop(columns = ['date'], inplace = True)

# Display sample data
transaction_df.tail()
# Out:
#                        name  amount        category
# date
# 2020-03-13        Starbucks    4.33  Food and Drink
# 2020-03-12         SparkFun   89.40  Food and Drink
# 2020-03-11     INTRST PYMNT   -4.22        Transfer
# 2020-03-01  United Airlines  500.00          Travel
# 2020-02-28             Uber    6.33          Travel

# %% [markdown]
# ---

# %% [markdown]
# # Income Analysis with Plaid
#
# In this section, you will use the Plaid Sandbox to complete the following:
#
# 1. Determine the previous year's gross income and print the results
#
# 2. Determine the current monthly income and print the results
#
# 3. Determine the projected yearly income and print the results

# %%
# Fetch the income data
income_response = client.Income.get(access_token)

# Print the income data
print(income_response['income'])
# Out:
# {'income_streams': [{'confidence': 0.99, 'days': 690, 'monthly_income': 500, 'name': 'UNITED AIRLINES'}], 'last_year_income': 6000, 'last_year_income_before_tax': 7285, 'max_number_of_overlapping_income_streams': 1, 'number_of_income_streams': 1, 'projected_yearly_income': 6085, 'projected_yearly_income_before_tax': 7389}

# %%
# Determine the previous year's gross income and print the results
previous_year_gross_income = income_response['income']['last_year_income_before_tax']
print(f"The previous year's gross income was {previous_year_gross_income}.")
# Out:
# The previous year's gross income was 7285.

# %%
# Determine the current monthly income and print the results
current_monthly_income = income_response["income"]["income_streams"][0]["monthly_income"]
print(f"The monthly income is: ${current_monthly_income}.")
# Out:
# The monthly income is: $500.

# %%
# Determine the projected yearly income and print the results
projected_yearly_income = income_response["income"]["projected_yearly_income_before_tax"]
print(f"The projected yearly gross income is: ${projected_yearly_income}.")
# Out:
# The projected yearly gross income is: $7389.

# %% [markdown]
# ---

# %% [markdown]
# # Budget Analysis
# In this section, you will use the transactions DataFrame to analyze the customer's budget
#
# 1. Calculate the total spending per category and print the results (Hint: groupby or count transactions per category)
#
# 2. Generate a bar chart with the number of transactions for each category
#
# 3. Calulate the expenses per month
#
# 4. Plot the total expenses per month

# %% [markdown]
# ### Calculate the expenses per category

# %%
# Compute the total expenses per category
expenses_per_category = transaction_df.groupby('category').sum()

# Display the expenses per category
print(expenses_per_category)
# Out:
#                   amount
# category
# Food and Drink   3317.19
# Payment          6310.50
# Recreation        235.50
# Shops            1500.00
# Transfer        20537.34
# Travel             35.19

# %%
# Create a spending categories pie chart.
expenses_per_category.plot.pie(subplots = True, title = "Spending Categories", figsize = (10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ffb90e8ba90>],
#       dtype=object)

# %% [markdown]
# ### Calculate the expenses per month

# %%
# Create a DataFrame with the total expenses
expenses_per_month = transaction_df.groupby(transaction_df.index.month).sum()

# Display sample data
print(expenses_per_month)
# Out:
#         amount
# date
# 2         6.33
# 3     11145.24
# 4     10645.24
# 5     10138.91

# %%
# Create a spending per month bar chart
expenses_per_month.plot(kind = 'bar', title = 'Spending per Month')
